# %%
def obtain_data(file):
    data = []
    dictionary = {}
    allKeys = []
    allVals = []
    
    with open(file,'r',encoding="utf8") as f:
        lines = f.readlines()
        #print(len(lines))
        index=0
        for i in range (len(lines)-2000):
            #print(lines[i]) #eg. 'Omg O' is line[0]
            if lines[i] == '\n':
                data.append(lines[index:i]) #append everything until it encounters a \n
                index = i+1
            lines[i] = lines[i].replace('\n','')# replace the \n at the end of each sentiments
            lines[i] = lines[i].split(' ') #split the line into their respective parts  
            #print(lines[i]) ##format = eg. ['Justin', 'B-neutral']
        #convert to keys and values (dict)
        for i in range(len(data)):
            #print(data[i])
            data_values = data[i]
            #print(data_values)
            for j in range(len(data_values)):
                if len(data_values[j]) > 2:
                    #print(data_values[j])
                    for k in range(1, len(data_values[j]) - 1):
                        data_values[j][0] += " "
                        data_values[j][0] += data_values[j][k]
            #key = [data_values[0]]
            #val = [data_values[len(data_values) - 1]]
                #print(data_values[0])
            key = [word[0] for word in data_values] #tweet
            val = [word[-1] for word in data_values] #sentiment
            #print(key)
            #print(val)
            data[i] = [key,val]
            #dictionary = dict(zip(key,val))
            #print(data[i])
        #data[i][0] gives the tweets
        for i in range(len(data)):
            for j in range(len(data[i][0])):
                allVals.append(data[i][1][j]) #appending the sentiments corresponding to the tweets
             
        for i in range(len(data)):
            for j in range(len(data[i][0])):
                #print(data[i][0][j]) #give each word
                allKeys.append(data[i][0][j])
        setKeys = set(allKeys)
        setVals = set(allVals)   

    return dict(data=data,x_set=setKeys,y_set=setVals)


obtain_data('sg_train')
# Out:
# {'data': [[['Omg',
#     "I'm",
#     'craving',
#     'UK',
#     'food',
#     'so',
#     'much',
#     'right',
#     'now',
#     'and',
#     'all',
#     'I',
#     'wanna',
#     'do',
#     'is',
#     'go',
#     'to',
#     'tescos',
#     'Mini',
#     'cheddars',
#     ',',
#     "Terry's",
#     'chocolate',
#     'orange',
#     'and',
#     'a',
#     'jam',
#     'donut',
#     'PLZZZZZ'],
#    ['O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'I-positive',
#     'O',
#     'B-positive',
#     'I-positive',
#     'I-positive',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'O']],
#   [['@JoeNBC',
#     'great',
#     'question',
#     'to',
#     '#GovWeld',
#     ',',
#     'how',
#     'can',
#     'u',
#     'do',
#     'better',
#     'and',
#     'be',
#     'successful',
#     'for',
#     'a',
#     'job',
#     'displacement',
#     'program',
#     '#BillClinton',
#     'tried',
#     'and',
#     'failed'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     'Lim',
#     'Chu',
#     'Kang',
#     'Camp',
#     '2',
#     'in',
#     'Singapore',
#     'https://t.co/pqcnSMebOw'],
#    ['O',
#     'O',
#     'B-negative',
#     'I-negative',
#     'I-negative',
#     'I-negative',
#     'I-negative',
#     'O',
#     'B-neutral',
#     'O']],
#   [['Monica',
#     '.',
#     'Gonna',
#     'wear',
#     'cum',
#     'stained',
#     'dress',
#     'to',
#     'next',
#     'debate'],
#    ['B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['@mew048',
#     'Yay',
#     '!',
#     'I',
#     'got',
#     'mine',
#     'from',
#     'Amazon',
#     ',',
#     'as',
#     'no',
#     'shops',
#     'here',
#     'stock',
#     'Sleek',
#     'products',
#     '.',
#     'Probably',
#     'cheaper',
#     'on',
#     'Amazon',
#     'too',
#     '!',
#     'It',
#     'was',
#     'about',
#     '2',
#     'quid'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Dammmm', 'tommy', '*', 'martins', 'voice', '*', '#RipTommyFord'],
#    ['O', 'B-positive', 'O', 'O', 'O', 'O', 'O']],
#   [['Four',
#     'goals',
#     '!',
#     'At',
#     'this',
#     'pace',
#     ',',
#     'I',
#     'may',
#     'watch',
#     'all',
#     '4,880',
#     'mins',
#     'of',
#     'this',
#     'Leafs',
#     'season',
#     '. .',
#     '&',
#     '#Matthews',
#     '488',
#     'goals',
#     'that',
#     "he's",
#     'on',
#     'pace',
#     'for',
#     '#TMLtalk',
#     '#Leafs'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@overdosedpills', 'in', 'shaa', 'allah', 'thank', 'u'],
#    ['O', 'O', 'O', 'B-positive', 'O', 'O']],
#   [["I'm",
#     'at',
#     'Bugis',
#     'Junction',
#     'in',
#     'Singapore',
#     'w',
#     '/',
#     '@_fifteennn',
#     'https://t.co/UIwQQqGQy9'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Watching',
#     'movie',
#     'in',
#     'SG',
#     '(',
#     '@',
#     'Cathay',
#     'Cineplexes',
#     '-',
#     '@cathaycineplex',
#     'in',
#     'Singapore',
#     ')',
#     'https://t.co/Oe30mkt7Ec'],
#    ['O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O']],
#   [['Brexit',
#     ',',
#     'stamp',
#     'duty',
#     'and',
#     'Bank',
#     'of',
#     'England',
#     'fail',
#     'to',
#     'deter',
#     'buy-to-let',
#     'https://t.co/7XU4OlRLaz',
#     'via',
#     '@ThisIsMoney'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@crcatrova',
#     'yes',
#     'setan',
#     'is',
#     'meant',
#     'to',
#     'burn',
#     'in',
#     'hell',
#     '.'],
#    ['O', 'O', 'B-negative', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'O']],
#   [['@El_Cliente',
#     'You',
#     'better',
#     'not',
#     'be',
#     'talking',
#     'about',
#     'my',
#     'Chelsea',
#     '.',
#     "She's",
#     'super',
#     'sweet',
#     'and',
#     'buys',
#     'me',
#     'candy',
#     'when',
#     "I'm",
#     'sad',
#     '.'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['VV',
#     '⚡',
#     '️',
#     '“',
#     'Create',
#     'your',
#     'own',
#     'Evian',
#     'iPhone',
#     'case',
#     '”',
#     'https://t.co/7kAKM5cj7S'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'B-neutral',
#     'O',
#     'O',
#     'O']],
#   [['Join',
#     'the',
#     'Aerotek',
#     'team',
#     '!',
#     'See',
#     'our',
#     'latest',
#     '#job',
#     'opening',
#     'here',
#     ':',
#     'https://t.co/Dq5d4EM9r1',
#     '#Healthcare',
#     '#Chaska',
#     ',',
#     'MN',
#     '#Hiring',
#     '#CareerArc'],
#    ['O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     '@KilangBateri',
#     'in',
#     'Johor',
#     'Bahru',
#     ',',
#     'Johor',
#     'https://t.co/Bba9BGtrA2'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O']],
#   [['Want',
#     'to',
#     'work',
#     'in',
#     '#MtLaurel',
#     ',',
#     'NJ',
#     '?',
#     'View',
#     'our',
#     'latest',
#     'opening',
#     ':',
#     'https://t.co/7EljpQYa0K',
#     '#Job',
#     '#Cosmetology',
#     '#Jobs',
#     '#Hiring',
#     '#CareerArc'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@udemy',
#     'Any',
#     'issues',
#     'with',
#     'https://t.co/Gjctj9tnA9',
#     '?',
#     'I',
#     'cannot',
#     'access',
#     'it',
#     'from',
#     'safari',
#     'on',
#     'MBP',
#     'despite',
#     'ALL',
#     'other',
#     'sites',
#     'tested',
#     'working',
#     'fine',
#     '.'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['MADD',
#     'Canada',
#     'are',
#     'showing',
#     'the',
#     'educational',
#     'film',
#     'to',
#     'students',
#     'across',
#     'the',
#     'province',
#     '.',
#     '@NTVNewsNL',
#     'https://t.co/SEppmQuTZu'],
#    ['O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@realDonaldTrump',
#     'join',
#     'her',
#     '@JamesComeyFBI',
#     '@Reince',
#     '@KellyannePolls',
#     '@treygowdy',
#     'Trey',
#     'speak',
#     'out',
#     'https://t.co/bhnCZviV8H'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O']],
#   [['Want',
#     'to',
#     'work',
#     'in',
#     '#Charlotte',
#     ',',
#     'North',
#     'Carolina',
#     '?',
#     'View',
#     'our',
#     'latest',
#     'opening',
#     ':',
#     'https://t.co/RuuqPhB7vg',
#     '#Job',
#     '#FinTech',
#     '#FinServ',
#     '#Accounting',
#     '#Jobs'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Do',
#     'we',
#     'look',
#     'alike',
#     '?',
#     'Had',
#     'a',
#     'great',
#     'time',
#     'hosting',
#     'the',
#     'Grand',
#     'Opening',
#     'of',
#     'Ganso',
#     'Manekineko',
#     'at',
#     'Orchard',
#     '…',
#     'https://t.co/uqXtHsYxhY'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'O',
#     'B-positive',
#     'O',
#     'O']],
#   [['@deeglenn25', 'whole', 'mixtape', 'a', 'classic'],
#    ['O', 'O', 'B-positive', 'O', 'O']],
#   [['Guys',
#     'Matthews',
#     'is',
#     'good',
#     '...',
#     'but',
#     "he's",
#     'no',
#     'Tyler',
#     'Motte'],
#    ['O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive']],
#   [['@HenryIrving10',
#     '@Turkishcypriot8',
#     '@_MRHemm_',
#     '1m',
#     'is',
#     'hardly',
#     'a',
#     'kings',
#     'ransom',
#     '.',
#     'Once',
#     'he',
#     'secured',
#     'promotion',
#     'he',
#     'had',
#     'his',
#     'budget',
#     'cut',
#     '2',
#     'seasons',
#     'on',
#     'the',
#     'trot'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O']],
#   [['to',
#     'work',
#     '(',
#     '@',
#     'I',
#     '-',
#     '495',
#     'in',
#     'Haverhill',
#     ',',
#     'MA',
#     ')',
#     'https://t.co/iIxykUkPI8'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O']],
#   [['Bill', 'Cowher', 'just', 'said', 'turnt', 'up'],
#    ['B-neutral', 'I-neutral', 'O', 'O', 'O', 'O']],
#   [["I'm",
#     'at',
#     'Lot',
#     'One',
#     'Shoppers',
#     "'",
#     'Mall',
#     'in',
#     'Singapore',
#     'w',
#     '/',
#     '@agareses',
#     '@sexismyclarity',
#     'https://t.co/mfQoUw05D1'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Selena', 'concert', 'later', 'on'], ['B-neutral', 'O', 'O', 'O']],
#   [['there',
#     'is',
#     'no',
#     'way',
#     'Austin',
#     'Matthews',
#     'is',
#     'human',
#     '#4goalsfirstgame'],
#    ['O', 'O', 'O', 'O', 'B-positive', 'I-positive', 'O', 'O', 'O']],
#   [['Generational',
#     '?',
#     'NYT',
#     'reported',
#     'Harvard',
#     'biz',
#     'school',
#     'boys',
#     'rate',
#     'the',
#     'women',
#     'if',
#     'they',
#     'r',
#     'f',
#     '☆',
#     'ckable',
#     '!',
#     '1/2',
#     'there',
#     '2',
#     'manage',
#     'family',
#     '$',
#     '.',
#     '…',
#     'https://t.co/kkUVfY5wnK'],
#    ['O',
#     'O',
#     'B-neutral',
#     'O',
#     'B-negative',
#     'I-negative',
#     'I-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     'Causeway',
#     'Point',
#     'in',
#     'Singapore',
#     'https://t.co/Nbra4BG4kk'],
#    ['O', 'O', 'B-neutral', 'I-neutral', 'O', 'B-neutral', 'O']],
#   [['Getting',
#     'help',
#     'when',
#     'you',
#     "didn't",
#     'even',
#     'ask',
#     'for',
#     'it',
#     '.',
#     'Thanks',
#     'Rudy',
#     'https://t.co/BudbiK8b8h'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O']],
#   [['-',
#     '#deplorables',
#     '#basementdwellers',
#     '#needylatinos',
#     '#superpredators',
#     '#Catholics',
#     '..',
#     'does',
#     '#hillaryclinton',
#     'like',
#     'any',
#     '#Americans',
#     '?',
#     '#arkansas',
#     '#tennessee'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@maiwaby',
#     '@georgegalloway',
#     '@BBCNews',
#     '@STWuk',
#     '@EmilyThornberry',
#     '@SuperStation95',
#     'all',
#     'the',
#     'papers',
#     'and',
#     't',
#     'v',
#     'stations',
#     'help',
#     'fan',
#     'the',
#     'flames',
#     'of',
#     'war'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Johannes',
#     'facetimed',
#     'me',
#     'today',
#     'and',
#     'told',
#     'me',
#     'one',
#     'day',
#     'he',
#     'is',
#     'going',
#     'to',
#     'move',
#     'to',
#     'America',
#     'and',
#     'sweep',
#     'me',
#     'away',
#     'to',
#     'LA',
#     'for',
#     'a',
#     'perfect',
#     'life'],
#    ['B-positive',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Photo',
#     'shoot',
#     'went',
#     'very',
#     'well',
#     '.',
#     'I',
#     'had',
#     'so',
#     'much',
#     'fun',
#     'hanging',
#     'out',
#     'with',
#     'Justin',
#     'Mayotte',
#     '.',
#     'Definitely',
#     'the',
#     'best',
#     'photographer',
#     'I',
#     'know',
#     '.'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Time',
#     'to',
#     'head',
#     'to',
#     'Chicago',
#     '!',
#     'Great',
#     'win',
#     'tonight',
#     'boys',
#     '!',
#     '#NLCS',
#     'https://t.co/bXLji5GQ4B'],
#    ['O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [["I'm",
#     'at',
#     'Singapore',
#     '@ChangiAirport',
#     'in',
#     'Singapore',
#     'w',
#     '/',
#     '@k_junliang',
#     'https://t.co/mfbMQEezK0'],
#    ['O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['Thanks',
#     'for',
#     'the',
#     'invite',
#     'ensen',
#     'and',
#     'dajie',
#     '!',
#     '!',
#     '!',
#     '❤',
#     '️',
#     '@',
#     '76',
#     'Guan',
#     'Chuan',
#     'Street',
#     'https://t.co/PuhHncvdm2'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O']],
#   [['Join',
#     'the',
#     'ABRA',
#     'Auto',
#     'Body',
#     'and',
#     'Glass',
#     'team',
#     '!',
#     'See',
#     'our',
#     'latest',
#     '#job',
#     'opening',
#     'here',
#     ':',
#     'https://t.co/EIYUxZyayP',
#     '#Technician',
#     '#Automotive',
#     '#Bellevue',
#     ',',
#     'WA'],
#    ['O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'I-positive',
#     'I-positive',
#     'I-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@yusufamumin',
#     'calling',
#     'an',
#     'audible',
#     'and',
#     'saying',
#     'Elizabeth',
#     ',',
#     'Schmidt',
#     "'",
#     's',
#     'old',
#     'gf',
#     '.',
#     'She',
#     'was',
#     'literally',
#     'useless'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@mitchellvii',
#     'guaranteed',
#     'the',
#     'media',
#     'is',
#     'going',
#     'to',
#     'make',
#     'a',
#     'big',
#     'deal',
#     'of',
#     'this',
#     '!',
#     '!',
#     'Hilary',
#     "'",
#     's',
#     'team',
#     'probably',
#     'hired',
#     'them',
#     '!',
#     'Ugg',
#     'makes',
#     'me',
#     'sick',
#     '!',
#     '!'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['My', 'whole', 'life', 'planned', 'out', 'on', 'Pinterest'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'B-positive']],
#   [['WIN',
#     '!',
#     'We',
#     'have',
#     'a',
#     'pair',
#     'of',
#     'tickets',
#     'to',
#     'giveaway',
#     'to',
#     'An',
#     'Evening',
#     'with',
#     'Ricky',
#     'Hatton',
#     'next',
#     'month',
#     '.',
#     'Enter',
#     'here',
#     ':',
#     '…',
#     'https://t.co/olxyMYFGd2'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@TheATrainSTL',
#     '@thelegendkil',
#     '@NTheZoneShow',
#     'Slams',
#     'on',
#     'Kelly',
#     'as',
#     'a',
#     'racist',
#     'are',
#     'historically',
#     'accurate',
#     '.',
#     'We',
#     'will',
#     'C',
#     'how',
#     'Kap',
#     'does',
#     '.',
#     'I',
#     'think',
#     'he',
#     'gets',
#     'hurt'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Love',
#     'these',
#     'women',
#     'doing',
#     'incredible',
#     'things',
#     'for',
#     'God',
#     '!',
#     '@DavisLirika',
#     '@',
#     'LIFE',
#     'Church',
#     'UK',
#     'https://t.co/AjSRREqAmT'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'I-positive',
#     'O']],
#   [['@FoxNews',
#     '@realDonaldTrump',
#     '@HillaryClinton',
#     'Melania',
#     'was',
#     'in',
#     'the',
#     'house',
#     'and',
#     'Trump',
#     'got',
#     'busted',
#     'by',
#     'the',
#     'butler',
#     '!',
#     '#tongue-in-mouth',
#     '#DropOutTrump'],
#    ['O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Happy',
#     'birthday',
#     'babe',
#     '...',
#     'May',
#     'Allah',
#     'bless',
#     'you',
#     '...',
#     'Amin',
#     '...',
#     'moga',
#     'cepat',
#     '2',
#     '…',
#     'https://t.co/DCwNmAe1qY'],
#    ['O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Happy',
#     'Birthday',
#     'fasikaaa',
#     '❤',
#     '❤',
#     'love',
#     'youu',
#     'https://t.co/ZednLNpBXH'],
#    ['O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O']],
#   [['@FLOTUS',
#     'Michelle',
#     'you',
#     'are',
#     'a',
#     'first',
#     'class',
#     'human',
#     'being',
#     '.',
#     'Thank',
#     'you',
#     'for',
#     'your',
#     'class',
#     ',',
#     'humanity',
#     ',',
#     'grace',
#     'and',
#     'decency',
#     '.',
#     'Love',
#     'Batman',
#     'xxx'],
#    ['O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['#HillaryClinton',
#     'MostTerrifyg',
#     '=',
#     'End',
#     'USA',
#     'w',
#     '/',
#     'ONE',
#     '#World',
#     'Govt',
#     '/',
#     '#OpenBordershttps',
#     ':/',
#     '/',
#     't.co/rbDj0Ywpmj',
#     '#Boston',
#     '#Worcester',
#     '#Lowell',
#     '#MIT',
#     '@HarvardWomen'],
#    ['B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['I',
#     'realise',
#     'that',
#     'there',
#     'has',
#     'been',
#     'made',
#     'much',
#     'problem',
#     'with',
#     'my',
#     'mac',
#     'since',
#     'i',
#     'update',
#     'it',
#     '.',
#     'Like',
#     '..',
#     'It',
#     'lags',
#     'too',
#     'much',
#     'but',
#     'there',
#     'isnt',
#     'much',
#     'apps',
#     'at',
#     'all',
#     '.'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@caspmax',
#     '@Dave_was_here',
#     '@kaimatai',
#     '@AmadeusAlmighty',
#     'Nobody',
#     'expects',
#     'the',
#     'Spanish',
#     'inquisition',
#     '.',
#     'https://t.co/sqsuJStWql'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-negative', 'I-negative', 'O', 'O']],
#   [['@quimrovira',
#     'You',
#     'may',
#     'have',
#     'smthg',
#     ',',
#     'there',
#     '.',
#     'However',
#     'I',
#     'hope',
#     'you',
#     'can',
#     'understand',
#     'why',
#     'I',
#     'still',
#     'think',
#     'the',
#     'Dutch',
#     'are',
#     'pretty',
#     'damned',
#     'tolerant',
#     ',',
#     'as',
#     'it',
#     'goes'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@nerdsbot',
#     '@liposuction2k16',
#     'be',
#     'sure',
#     'to',
#     'explore',
#     'all',
#     'of',
#     'our',
#     'financial',
#     'aid',
#     'options',
#     'and',
#     'file',
#     'your',
#     'FAFSA',
#     'to',
#     'maximize',
#     'aid',
#     'potential',
#     '!',
#     '❤',
#     '️',
#     '️'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Join',
#     'the',
#     'AMC',
#     'Theatres',
#     'team',
#     '!',
#     'See',
#     'our',
#     'latest',
#     '#job',
#     'opening',
#     'here',
#     ':',
#     'https://t.co/0HPBUCD952',
#     '#Retail',
#     '#LakeInTheHills',
#     ',',
#     'IL',
#     '…',
#     'https://t.co/VqGqdDjdva'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['If',
#     'the',
#     'Cubs',
#     'win',
#     'I',
#     'have',
#     'a',
#     'few',
#     'friends',
#     'that',
#     "I'll",
#     'be',
#     'happy',
#     'for',
#     'but',
#     'the',
#     'rest',
#     'of',
#     'you',
#     'Cubs',
#     'fans',
#     'can',
#     'kiss',
#     'my',
#     'ass',
#     '.'],
#    ['O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Uh',
#     'the',
#     'new',
#     'episode',
#     'for',
#     'American',
#     'Horror',
#     'Story',
#     'and',
#     'South',
#     'Park',
#     'both',
#     'come',
#     'on',
#     'tonight',
#     'at',
#     '9',
#     '☹',
#     '️',
#     '️',
#     '️',
#     'why',
#     'is',
#     'life',
#     'so',
#     'hard',
#     'omg'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Happy', 'Birthday', 'Tammy', 'https://t.co/QMUjHdksvh'],
#    ['O', 'O', 'B-positive', 'O']],
#   [['@CherylKennedeh',
#     'found',
#     'a',
#     'lot',
#     'of',
#     'flaws',
#     'in',
#     'this',
#     '.',
#     'If',
#     'you',
#     'dreamt',
#     'about',
#     'J',
#     'Goldblum',
#     'but',
#     'he',
#     "didn't",
#     'ask',
#     'about',
#     'me',
#     'BUT',
#     'we',
#     'friends',
#     'then',
#     "I'm",
#     'interested'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'I-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@TammyTownhouses',
#     "She's",
#     'funny',
#     'and',
#     'makes',
#     'me',
#     'smile',
#     'everyday',
#     'on',
#     'Twitter',
#     '.',
#     'We',
#     'need',
#     'her',
#     'around',
#     '!'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm", 'at', 'Dorothy', 'Perkins', 'https://t.co/Xw2LGpAtxs'],
#    ['O', 'O', 'B-neutral', 'I-neutral', 'O']],
#   [['Molly', ':', '0This', 'two', 'day', 'week', 'of', 'classes', ':', '7'],
#    ['B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['As',
#     'soon',
#     'as',
#     'I',
#     'graduate',
#     "I'm",
#     'moving',
#     'out',
#     'of',
#     'AZZ',
#     "I'll",
#     'rather',
#     'live',
#     'in',
#     'MI',
#     'fr'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O']],
#   [['@haiiraw', '@hornyscopes', 'it', 'made', 'me', 'laugh'],
#    ['O', 'O', 'O', 'O', 'B-positive', 'O']],
#   [['THATS',
#     'THE',
#     'BUBBLE',
#     '!',
#     '!',
#     '!',
#     'Is',
#     'this',
#     'the',
#     'one',
#     'that',
#     'was',
#     'in',
#     'Chris',
#     "'",
#     'mouth',
#     '?',
#     '?',
#     '?',
#     '@ColleenB123',
#     '@ballingerfamily',
#     '@hatersbackoff',
#     '…',
#     'https://t.co/FE2Y34vIu4'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Strike',
#     '❤',
#     '️',
#     '@',
#     'Sister',
#     'Bay',
#     'Bowl',
#     'https://t.co/LKbYPUCXS9'],
#    ['O', 'O', 'O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'O']],
#   [['Listen',
#     'to',
#     'City',
#     '|',
#     'Josh',
#     'Coakley',
#     '|',
#     'Out',
#     '21/10',
#     '/',
#     '16',
#     '|',
#     'by',
#     '@OneFoldDigital',
#     'https://t.co/eFaWPq0Pz9',
#     '#ADE16',
#     '#deeptech',
#     '…',
#     'https://t.co/sKGodFjdZI'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@brianmoore1',
#     'its',
#     'amy',
#     'winehouse',
#     'but',
#     'cant',
#     'think',
#     'what',
#     'its',
#     'called',
#     '#ttat'],
#    ['O', 'O', 'B-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['this',
#     'is',
#     'from',
#     'the',
#     'Netflix',
#     'doc',
#     '13th',
#     '.',
#     'highly',
#     'recommend',
#     'it',
#     '.',
#     'https://t.co/l8FkkCwYt4'],
#    ['O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [["I'm",
#     'at',
#     'Orchard',
#     'Plaza',
#     'in',
#     'Singapore',
#     'https://t.co/fIUlQLnJFG'],
#    ['O', 'O', 'B-neutral', 'I-neutral', 'O', 'O', 'O']],
#   [['@buff_egan',
#     'will',
#     'Podge',
#     'go',
#     'pick',
#     'the',
#     'hurling',
#     'over',
#     'the',
#     'Gaelic',
#     '?',
#     'I',
#     'reckon',
#     'he',
#     'will',
#     '..'],
#    ['O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     '1st',
#     'Battalion',
#     'Singapore',
#     'Guards',
#     'https://t.co/u74dB5816d'],
#    ['O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'I-neutral', 'O']],
#   [['im',
#     'not',
#     'crying',
#     'im',
#     'not',
#     'crying',
#     'that',
#     'im',
#     'not',
#     'at',
#     'selena',
#     "'",
#     's',
#     'concert',
#     '☹',
#     '️',
#     '☹',
#     '️',
#     '☹',
#     '️'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     "McDonald's",
#     '/',
#     'McCafé',
#     'in',
#     'Masai',
#     ',',
#     'Johor',
#     'https://t.co/Vknp0ecFNh'],
#    ['O',
#     'O',
#     'B-neutral',
#     'O',
#     'B-neutral',
#     'O',
#     'B-neutral',
#     'O',
#     'B-neutral',
#     'O']],
#   [['Subha', 'damn', 'cute', 'I', 'cannot'],
#    ['B-positive', 'O', 'O', 'O', 'O']],
#   [['Interested',
#     'in',
#     'a',
#     '#job',
#     'in',
#     '#Snoqualmie',
#     ',',
#     'WA',
#     '?',
#     'This',
#     'could',
#     'be',
#     'a',
#     'great',
#     'fit',
#     ':',
#     'https://t.co/Yfs2EWFsGt',
#     '#Hospitality',
#     '#Hiring',
#     '#CareerArc'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     'Blk',
#     '137',
#     'Lorong',
#     'Ah',
#     'Soo',
#     'in',
#     'Singapore',
#     'https://t.co/nPi97DNqFR'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O']],
#   [["I'm", 'at', 'Energym', 'in', 'Singapore', 'https://t.co/UoQ5g8fOT4'],
#    ['O', 'O', 'B-neutral', 'O', 'B-neutral', 'O']],
#   [['@Exploring101',
#     'yadda',
#     'yadda',
#     'all',
#     'over',
#     'the',
#     'place',
#     'in',
#     'a',
#     'Minnesota',
#     'mouse',
#     'voice'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O']],
#   [['Krugman',
#     "'",
#     's',
#     'Nobel',
#     'prize',
#     '(',
#     'for',
#     'trade',
#     'theory',
#     ')',
#     'is',
#     'as',
#     'indicative',
#     'of',
#     'his',
#     'macro',
#     '#econ',
#     'acumen',
#     'as',
#     'Obama',
#     "'",
#     's',
#     'is',
#     'of',
#     'his',
#     'contributi',
#     '…',
#     'https://t.co/dNsgwOOjvI'],
#    ['B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     '@SwankAndswine',
#     'in',
#     'Portland',
#     ',',
#     'OR',
#     'w',
#     '/',
#     '@jcl324',
#     '@liberatr',
#     'https://t.co/iH9ZUPxsLU'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Ticketmaster',
#     'sending',
#     'tickets',
#     'straight',
#     'to',
#     'GetMeIn',
#     'to',
#     'charge',
#     'double',
#     ',',
#     'biggest',
#     'scam',
#     'around'],
#    ['O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['If',
#     'this',
#     'works',
#     'out',
#     'I',
#     'should',
#     'be',
#     'moving',
#     'to',
#     'LA',
#     'soon',
#     '.'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O']],
#   [['#BBCQT',
#     'I',
#     "don't",
#     'agree',
#     'with',
#     'Isabel',
#     'Oakeshott',
#     'from',
#     'the',
#     'Daily',
#     'Mail',
#     '.',
#     'She',
#     "hasn't",
#     'said',
#     'anything',
#     'yet',
#     'but',
#     "I'm",
#     'getting',
#     'this',
#     'in',
#     'first',
#     '.'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     'Canal',
#     '@',
#     'Changi',
#     'in',
#     'Singapore',
#     'https://t.co/dqtQts7bha'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O']],
#   [['...',
#     'oh',
#     'for',
#     'fucking',
#     'fuck',
#     'sake',
#     '.',
#     '"',
#     'Game',
#     'of',
#     'thrones',
#     'is',
#     'racist',
#     '!',
#     '"',
#     'Now',
#     '.',
#     'Because',
#     'period',
#     'pieces',
#     'care',
#     'about',
#     'PC',
#     'culture',
#     '.',
#     'Right',
#     '?',
#     'https://t.co/PVkYnAD3mu'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     'Jurong',
#     'Regional',
#     'Library',
#     '-',
#     '@publiclibrarysg',
#     'in',
#     'Singapore',
#     'https://t.co/bXYQDYt27E'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O']],
#   [['@RYANNCSY', 'What', '.', 'see', 'you', 'tmr', '.'],
#    ['B-neutral', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['I',
#     'turned',
#     '#bbcqt',
#     'off',
#     '.',
#     "I'm",
#     'so',
#     'sick',
#     'of',
#     'the',
#     'rampant',
#     'BBC',
#     'bias',
#     '.',
#     'Dimbleby',
#     'is',
#     'a',
#     'joke',
#     'now',
#     '.',
#     'SNP',
#     'and',
#     'Corbyn',
#     'bashing',
#     'obsessives'],
#    ['B-neutral',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'B-negative',
#     'O',
#     'O']],
#   [['.',
#     '@billclinton',
#     'made',
#     'a',
#     'surprise',
#     'stop',
#     'in',
#     'Ames',
#     'on',
#     'Tuesday',
#     'at',
#     'a',
#     'Starbucks',
#     'near',
#     'campus',
#     '.',
#     'Details',
#     ':',
#     'https://t.co/3AlMTMkQJM'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Join',
#     'the',
#     'SONIC',
#     'Drive-In',
#     'team',
#     '!',
#     'See',
#     'our',
#     'latest',
#     '#job',
#     'opening',
#     'here',
#     ':',
#     'https://t.co/HOQUmkKswP',
#     '#SONIC',
#     '#Hospitality',
#     '#Tampa',
#     ',',
#     'FL',
#     '#Hiring',
#     '#CareerArc'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['1211',
#     '7th',
#     'Ave',
#     'N',
#     ',',
#     'Texas',
#     'City',
#     ',',
#     'TX',
#     '77590',
#     ',',
#     '$',
#     '12,000',
#     'https://t.co/eVMIjhZWXv'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Welcome', 'home', 'kabuto', ':)', 'https://t.co/GPzxKdLVkQ'],
#    ['O', 'O', 'B-positive', 'O', 'O']],
#   [['@EVE_Scatha',
#     '@SindelPellion',
#     'We',
#     'need',
#     'a',
#     'talk',
#     'Scatha',
#     '...',
#     ';)'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O']],
#   [['King', 'Kendrick'], ['B-neutral', 'I-neutral']],
#   [['@ZACHARIAH_LVII',
#     'mmmh',
#     ',',
#     'please',
#     '.',
#     'You',
#     "don't",
#     'gotta',
#     'lie',
#     ',',
#     'when',
#     'we',
#     'BOTH',
#     'know',
#     'the',
#     'truth'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@MagnaCartaRules',
#     '@StephenGethins',
#     'UK',
#     'Government',
#     'is',
#     'in',
#     'control',
#     'of',
#     'energy',
#     'policy',
#     '&',
#     'revenues',
#     '.',
#     'They',
#     'wasted',
#     '100s',
#     'of',
#     'billions',
#     '.'],
#    ['B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@christbone222',
#     '@Frater_Mashpin',
#     "don't",
#     'have',
#     'to',
#     'believe',
#     'lies',
#     'about',
#     'Trump',
#     'really',
#     '.',
#     "He's",
#     'bad',
#     'enough',
#     'IRL'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Why',
#     'is',
#     'Trevor',
#     'Siemian',
#     'having',
#     'to',
#     'pass',
#     'the',
#     'ball',
#     '50',
#     'times',
#     '?',
#     'Have',
#     'all',
#     'Broncos',
#     'RB',
#     "'",
#     's',
#     'lost',
#     'a',
#     'leg',
#     'or',
#     'something',
#     '?'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'I-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Work-life',
#     'balance',
#     ':',
#     'reading',
#     'my',
#     'favorite',
#     'book',
#     'after',
#     'finishing',
#     'work',
#     'at',
#     '12.30',
#     '…',
#     '(',
#     'at',
#     'Park',
#     'Avenue',
#     'Changi',
#     'Hotel',
#     ')',
#     '[',
#     'pic',
#     ']',
#     '—',
#     'https://t.co/X9xnNIlcR0'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Sunset',
#     'over',
#     'Seneca',
#     'Lake',
#     ',',
#     'Finger',
#     'Lakes',
#     'of',
#     'NY',
#     '.',
#     '#sunsetwx',
#     'https://t.co/nPNRgFBLHE'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O']],
#   [['nighty',
#     'night',
#     '✨',
#     '@',
#     'Plaza',
#     'Angsana',
#     ',',
#     'Johor',
#     'Bharu',
#     '.',
#     'https://t.co/5QGI7dh7kc'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O']],
#   [['I',
#     'learned',
#     'today',
#     'that',
#     'going',
#     'running',
#     'on',
#     'the',
#     'esplanade',
#     'is',
#     'a',
#     'bad',
#     'idea',
#     'because',
#     'I',
#     'will',
#     'inevitably',
#     'stop',
#     'and',
#     'marvel',
#     'at',
#     'the',
#     'beauty',
#     'of',
#     'the',
#     'world'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive']],
#   [['@Baby_Tess_',
#     '@Double_B7',
#     '@sydney__Elise',
#     'Best',
#     'Halloween',
#     'hands',
#     'down'],
#    ['O', 'O', 'O', 'O', 'B-positive', 'O', 'O']],
#   [['Drinking',
#     'a',
#     'Watermelon',
#     'Blonde',
#     'by',
#     '@ninelocksbrew',
#     'at',
#     '@ninelocksbrew',
#     '—',
#     'https://t.co/HOFJDI0FMb',
#     '#photo'],
#    ['O', 'O', 'B-neutral', 'I-neutral', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [['Dean',
#     'should',
#     'tell',
#     'Mary',
#     'they',
#     'saved',
#     'earth',
#     'a',
#     'few',
#     'times',
#     '.',
#     '#Supernatural'],
#    ['B-positive',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['eHealth',
#     'Ireland',
#     'getting',
#     'on',
#     'the',
#     'personas',
#     'bandwagon',
#     '.',
#     'Good',
#     'to',
#     'see',
#     'these',
#     'steps',
#     'toward',
#     'user-centricity',
#     '.',
#     '#UCD16',
#     '#digitalhealth',
#     '#ehealth'],
#    ['B-positive',
#     'I-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Chargers', "aren't", 'a', 'bad', 'team'],
#    ['B-positive', 'O', 'O', 'O', 'O']],
#   [['omg', 'Halizah', 'singing', 'is'], ['O', 'B-positive', 'O', 'O']],
#   [['@CNN',
#     'CNN',
#     'please',
#     'dont',
#     'make',
#     'me',
#     'vote',
#     'for',
#     'Trump',
#     'because',
#     'of',
#     'this',
#     'BS',
#     ',',
#     'I',
#     'dont',
#     'like',
#     'Trump',
#     'but',
#     'CNN',
#     'is',
#     'not',
#     'a',
#     'media',
#     'outlet',
#     ',',
#     'pathetic',
#     '@andersoncooper'],
#    ['B-negative',
#     'I-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative']],
#   [['Really',
#     '?',
#     '!',
#     'Minimum',
#     '3',
#     'days',
#     'for',
#     '#netlinktrust',
#     'to',
#     'sort',
#     'out',
#     'my',
#     'home',
#     'WiFi',
#     '#smartnation'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Cleared',
#     ':',
#     'Incident',
#     'on',
#     '#I678',
#     'SB',
#     'from',
#     'Queens',
#     ';',
#     'Bronx',
#     'County',
#     'Line',
#     '-',
#     'Whitestone',
#     'Bridge',
#     'Toll',
#     'Plaza',
#     'to',
#     'Northern',
#     '...'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'I-positive',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['@bonesgentle',
#     '@mtvasia',
#     'FUCK',
#     'YES',
#     '.',
#     'CONGRATS',
#     'JOEL',
#     'YOU',
#     'DESERVE',
#     'THIS',
#     '.',
#     '✨'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O']],
#   [['If',
#     'you',
#     'want',
#     'to',
#     'buy',
#     'ribs',
#     'stick',
#     'to',
#     'kc',
#     '.',
#     'Nebraska',
#     'step',
#     'your',
#     'game',
#     'up',
#     'that',
#     'was',
#     'garbage',
#     '.'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['vans',
#     'sk8',
#     'hi',
#     'reissue',
#     'dress',
#     'blue',
#     '#vansoriginal',
#     '#vansheadid',
#     '#sk8hi',
#     '#skateshoes',
#     '#skateboard',
#     '…',
#     'https://t.co/ugmkegnbZR'],
#    ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-neutral', 'O', 'O']],
#   [["I'm",
#     'at',
#     'Central',
#     'Delights',
#     'in',
#     'Singapore',
#     'https://t.co/AElBieWu7R'],
#    ['O', 'O', 'B-neutral', 'I-neutral', 'O', 'B-positive', 'O']],
#   [['Happy', 'birthday', 'ZEKE', '❗', '️', '️', 'for', '#17'],
#    ['O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O']],
#   [['@tim_micallef',
#     'will',
#     'Calgary',
#     'be',
#     'doing',
#     'with',
#     'with',
#     'Matthew',
#     'Tkachuk',
#     'tonight',
#     'when',
#     'he',
#     'scores',
#     '4',
#     '?'],
#    ['O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["I'm",
#     'at',
#     'Gateway',
#     'West',
#     'in',
#     'Singapore',
#     'https://t.co/zJ8GLkGB3u'],
#    ['O', 'O', 'B-neutral', 'I-neutral', 'I-neutral', 'I-neutral', 'O']],
#   [['My',
#     'latest',
#     'painting',
#     'with',
#     'my',
#     'favorite',
#     'brush',
#     '.',
#     '@Kuretake_ZIG',
#     '#watercolor',
#     '#watercolorpainting',
#     '…',
#     'https://t.co/ofbN5bTwzb'],
#    ['O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Got',
#     'work',
#     'done',
#     'today',
#     '.',
#     'Now',
#     "I'm",
#     'happy',
#     '!',
#     '#workday',
#     '#marinabay',
#     '#floral',
#     '@',
#     'Singapore',
#     'https://t.co/9JxgCN8rZK'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O']],
#   [['confused', 'puppy', '@jarpad', '#spntor', 'https://t.co/0B7vyXmy3q'],
#    ['O', 'O', 'B-negative', 'O', 'O']],
#   [["I'm",
#     'at',
#     'Lot',
#     'One',
#     'Shoppers',
#     "'",
#     'Mall',
#     'in',
#     'Singapore',
#     'https://t.co/3HYT4wl5xQ'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O']],
#   [['@MSNBC',
#     'How',
#     'does',
#     'it',
#     'feel',
#     'to',
#     'get',
#     'your',
#     'ass',
#     'kicked',
#     'by',
#     '@realDonaldTrump',
#     'Your',
#     'channel',
#     'is',
#     'a',
#     'disgrace',
#     'to',
#     'Christianity',
#     'in',
#     'AMerica',
#     'LIE',
#     '<',
#     'LIE',
#     'LIE',
#     '!',
#     'RT'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Curt',
#     'Schilling',
#     'thinks',
#     '#DonaldTrump',
#     'eyeing',
#     'a',
#     '10',
#     '-',
#     'year-old',
#     'is',
#     'totally',
#     'normal',
#     'Hint',
#     ',',
#     "it's",
#     'not',
#     '!',
#     '…',
#     'https://t.co/HM9IKxMx8a'],
#    ['B-negative',
#     'I-negative',
#     'O',
#     'B-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Actuellement',
#     '«',
#     'Dark',
#     'Necessities',
#     '»',
#     'de',
#     '«',
#     'Red',
#     'Hot',
#     'Chili',
#     'Peppers',
#     '»',
#     'sur',
#     'Virgin',
#     'Radio',
#     '#ckoicetitre'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'I-positive',
#     'I-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [["Dylan's",
#     'face',
#     'going',
#     'through',
#     'farmageddon',
#     'omg',
#     'I',
#     'feel',
#     'sorry',
#     'for',
#     'himmm',
#     '@capliverpool',
#     '@MrDylanEvans'],
#    ['B-negative', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']],
#   [["I'm",
#     'at',
#     'Blk',
#     '105',
#     'Rivervale',
#     'Walk',
#     'in',
#     'Singapore',
#     'https://t.co/okzbhVoMli'],
#    ['O',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'I-neutral',
#     'I-neutral',
#     'O',
#     'B-neutral',
#     'O']],
#   [['Ha',
#     "he's",
#     'pouting',
#     'because',
#     'Jason',
#     'Witten',
#     'is',
#     '10',
#     'times',
#     'the',
#     'ball',
#     'player',
#     'he',
#     'will',
#     'ever',
#     'be',
#     'https://t.co/zFSBz7CWdO'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['#pathdaily',
#     '(',
#     'with',
#     'Firsty',
#     ',',
#     'Tri',
#     ',',
#     'and',
#     'kak',
#     'at',
#     'Mie',
#     'Tarempa',
#     ')',
#     '[',
#     'pic',
#     ']',
#     '—',
#     'https://t.co/KGekV2Gv7y'],
#    ['O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'B-neutral',
#     'I-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Anthony',
#     'Bourdain',
#     'once',
#     'went',
#     'head',
#     'over',
#     'heels',
#     'with',
#     'chicken',
#     'rice',
#     '.',
#     'So',
#     'was',
#     'I.This',
#     "ain't",
#     'Tian-Tian',
#     '…',
#     'https://t.co/7r6zzAAImH'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-positive',
#     'I-positive',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['year',
#     ')',
#     '.',
#     'what',
#     'matters',
#     'now',
#     'is',
#     ':',
#     'Are',
#     'People',
#     'Talking',
#     'About',
#     'Your',
#     'Show',
#     '?',
#     'are',
#     'you',
#     'trending',
#     'on',
#     'twitter',
#     '?',
#     'facebook',
#     '?',
#     'tumblr',
#     '?',
#     'how',
#     'many',
#     'clicks',
#     'do',
#     'you',
#     'get',
#     '?'],
#    ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'B-neutral',
#     'O',
#     'B-neutral',
#     'O',
#     'B-neutral',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['Ok',
#     "'",
#     'Officer',
#     'Ottawa',
#     "'",
#     '.',
#     '@',
#     'the',
#     'water',
#     '+',
#     'sewer',
#     'site',
#     '..',
#     'I',
#     'get',
#     'the',
#     'drift',
#     '..',
#     'omfg',
#     '...',
#     "y'all",
#     'might',
#     'want',
#     'to',
#     'tone',
#     'down',
#     'the',
#     'attitude',
#     '...',
#     '#CityofOttawa'],
#    ['O',
#     'O',
#     'B-negative',
#     'I-negative',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O']],
#   [['#Dad',
#     'said',
#     '"',
#     'But',
#     'first',
#     ',',
#     'let',
#     'us',
#     'take',
#     'a',
#     '#Selfie',
#     '"',
#     'lol',
#     '#ParentsinSG',
#     '@',
# ...
#   'ean',
#   'Cambridge',
#   'Mugen',
#   '@eddiesjb_',
#   'hoax',
#   'VOICE',
#   'NC16',
#   'https://t.co/3DWjPagZFg',
#   'killin',
#   '@_missceee',
#   'https://t.co/WOPfWEIhja',
#   'than',
#   '@missA_suzy',
#   'barely',
#   'tbarhale',
#   'yosi',
#   'padding',
#   'https://t.co/VEVeD5rfuy',
#   'Ayer',
#   '@Ayda_Jebat',
#   'Kingz',
#   '#michaelhow',
#   '#Andre',
#   '5th',
#   'Mick',
#   'snorts',
#   'unreal',
#   'Gombak',
#   '#ST912',
#   '@LondonMidland',
#   'Galatians',
#   'Cobh',
#   'https://t.co/qIlenmDLYn',
#   '@akakatie1',
#   '@go_touche',
#   '@sclm93',
#   'Planet',
#   'subway',
#   'Boycott',
#   'resolve',
#   'Singtel',
#   'Politifact',
#   'allergy',
#   'Joey',
#   '@WiseKarl',
#   'announced',
#   '@StephSammons',
#   'Rec',
#   'https://t.co/aIgi6Ocbgs',
#   'brother',
#   'McClaren',
#   'X-Campus',
#   'proverbs',
#   'https://t.co/m3JZ8Iivlq',
#   'https://t.co/kB0jVNiuwl',
#   'PLEASE',
#   'https://t.co/Ap0QsomlT9',
#   'gee',
#   'governor',
#   'State',
#   '@stophateuk',
#   'HUANG',
#   'https://t.co/JwPULMwwi2',
#   'https://t.co/VLX5jK6BsO',
#   'fox',
#   ':|',
#   'https://t.co/q4fX2OlZrR',
#   'Guess',
#   'https://t.co/8skCwECUWN',
#   'JASPER',
#   'https://t.co/1nWLMAe40C',
#   'mostly',
#   "great-nephew's",
#   'Griffin',
#   'flick',
#   'bitmoji',
#   'https://t.co/eS7MaXD098',
#   '00e',
#   'cannibalistic',
#   'precedent',
#   '#debates',
#   'https://t.co/R8wNjSQN8W',
#   'Samsung',
#   'https://t.co/RUQqXYhIii',
#   'ANATOMY',
#   'TRAVELING',
#   '♥',
#   'https://t.co/LrufZnLK6E',
#   '@RoseEllenDix',
#   'Major',
#   'Vine',
#   '@ToysRUsSg',
#   '#175hero',
#   'Would',
#   'meeeee',
#   'timeless',
#   'yayoh',
#   'SQUISHYSO',
#   '@jessica_jane96',
#   'https://t.co/SKtd2o02bI',
#   'bumped',
#   'heat',
#   'https://t.co/rZ8bCnJ3r4',
#   '@DalStudentUnion',
#   'Gorgeous',
#   'starts',
#   'Poireau',
#   '#Havertown',
#   'reporters',
#   'finished',
#   '@keithfanalis',
#   'https://t.co/BmleLe9S4F',
#   'Irony',
#   '@TheNameIsCraig',
#   '@dcfcacademy',
#   'Newcastle',
#   'https://t.co/o018j74Inz',
#   'Raise',
#   "Singapore's",
#   'Supplies',
#   'asap',
#   'Offaly',
#   'Peep',
#   'https://t.co/89oOsZCMAx',
#   'applauded',
#   'Southeast',
#   'Turtleshead',
#   'randomly',
#   'Brock',
#   'https://t.co/AxluA0lxl1',
#   'sip',
#   'Psy',
#   '@pschlimm',
#   'psychology',
#   'https://t.co/g5J87SpyZR',
#   'https://t.co/OznO9f0kXH',
#   'Finchley',
#   '#clay',
#   'Lads',
#   'opportunists',
#   'lotta',
#   '10-11',
#   'https://t.co/ZPorPjvDjz',
#   'geno',
#   'Maharashtra',
#   '@bbc',
#   '#Sunday',
#   '31.0',
#   '@com196',
#   'Nativity',
#   'Last',
#   'https://t.co/ySwAcdq1Of',
#   'https://t.co/r13IrGtXQ8',
#   'https://t.co/rkzJ2Tj5cD',
#   'assets',
#   '@purplixes',
#   'https://t.co/Ce1rMyLBeP',
#   'Rotten',
#   'Corkk',
#   'updated',
#   'nightstand',
#   '@homo_sapien27',
#   'Bake',
#   'script',
#   '#ADAHIC',
#   'https://t.co/jyiGW4cr2L',
#   '@Busted',
#   'Zoe',
#   'SLEEP',
#   '321',
#   'arron.lim',
#   'Darren',
#   '#visitors',
#   '@powerofcolour',
#   '#TheCPATaxProblemSolver',
#   '3-4',
#   '@Givemeabiscuit',
#   'Han',
#   'https://t.co/urQ7uRXmoP',
#   'sazgrieves',
#   'FiFi',
#   'staying',
#   'Jessie',
#   'https://t.co/HlI3fiCQHH',
#   "#BCBSMA's",
#   '@RHoogland',
#   'secured',
#   '@WorldOfStu',
#   'haircare',
#   'https://t.co/ZMas5ZfhiR',
#   'dagger',
#   'https://t.co/JKMztycL9P',
#   '@E',
#   'Bana',
#   '@goldenroadbrew',
#   'https://t.co/7oB9GJE0BA',
#   'Damai',
#   '#地表最强2016',
#   'https://t.co/BpWDWOXdlZ',
#   'S7',
#   'showcasing',
#   '#Cooperstown',
#   'https://t.co/53nY42y6kP',
#   'BN',
#   'Red',
#   'Nicks',
#   '@DunkinDonuts',
#   'https://t.co/JvblQzORGI',
#   'ymca',
#   '01902',
#   '#health',
#   '#interior',
#   'https://t.co/hzzy5QZIVn',
#   '#gymlife',
#   'JOIN',
#   '@Erika',
#   'HYPE',
#   'Osama',
#   'Sponsors',
#   'CAMP',
#   '@neonpxrvs',
#   'accolade',
#   'ps2',
#   'https://t.co/Xo1lFQNy6L',
#   'sums',
#   'WSU',
#   '@forbesmasters',
#   'Marilyn',
#   '@steevXIII',
#   'https://t.co/vIodO2Exsf',
#   '@samantha_a_s',
#   '#TeenChoice',
#   'https://t.co/caPw8xJdT5',
#   'deliveryy',
#   'TROY',
#   'Poseidonn',
#   'easy',
#   'cave',
#   'FASS',
#   'Almond',
#   'Beydouns',
#   '#TrumpTrain',
#   'https://t.co/pKlbxaNvU2',
#   'https://t.co/FeOEcCA5a8',
#   'https://t.co/i3HOjLZcN7',
#   '#F1Sale',
#   'Politics',
#   'IPR',
#   'Shogun',
#   'https://t.co/Gm5t4blnBu',
#   'race',
#   'sea',
#   'https://t.co/7n9ejhsfGj',
#   '@mrleeeugene',
#   '@BounceSpace',
#   '#katiehopkins',
#   'WANTS',
#   'UPLOADS',
#   'Mercy',
#   '#theatrelife',
#   '@McDonaldsUK',
#   'unpaid',
#   '@BettyBoo81',
#   'https://t.co/NAIlVQDCPF',
#   'stationary',
#   'rumour',
#   'https://t.co/msnLJoLCZa',
#   'isnt',
#   'Wharf',
#   'https://t.co/3h3AWkJCEX',
#   'belgium',
#   'kellin',
#   '@smgm05',
#   'Pale',
#   'B2B',
#   '#WestBradford',
#   'Brain',
#   'BRIBED',
#   'Langley',
#   'Pumpkin',
#   '@Wild949',
#   '@theboomcard',
#   "no's",
#   'had',
#   '#LadyMacbeth',
#   'Pairc',
#   '@RicardoLamasMMA',
#   '@FirstManchester',
#   'beta',
#   'https://t.co/Z8ZSztgC2l',
#   '3M',
#   'https://t.co/KOnETpVn5S',
#   'broadband',
#   '21km',
#   '@magicfm',
#   'Made',
#   'adorably',
#   'gun',
#   'https://t.co/bQHSXXNgjY',
#   'https://t.co/02IylciYy4',
#   'smashes',
#   'https://t.co/Hp512TrfO3',
#   '#A08YX',
#   'https://t.co/BUmR4WblTc',
#   'Smash',
#   "pout'n'tongue",
#   'twat',
#   'https://t.co/rtSnWDFTxX',
#   '#CausewayChallenge',
#   'Body',
#   'https://t.co/EZ6ALcYS3F',
#   '#Bakersfield',
#   'champion',
#   'https://t.co/xW2PjEzVWU',
#   'part',
#   '20A1',
#   'Skyline',
#   '@vaopera',
#   'velour',
#   'https://t.co/Cr48rnH76G',
#   'Spiritwear',
#   '@_xinluvs_',
#   '#Mossside',
#   'char',
#   'https://t.co/fSYQ5cxU4Y',
#   'sleeve',
#   'STORM',
#   '@_metafizik',
#   'Bartlet',
#   '@FiestaSTTrophy',
#   '#region96',
#   'nephew',
#   'shorter',
#   'condolences',
#   'https://t.co/SfOyizO8ZG',
#   '74',
#   'https://t.co/KUV9bqdkjJ',
#   '#SensArmy',
#   '#byebye',
#   'Wey',
#   '#beachbum',
#   'Coder',
#   '#mountiepride',
#   'https://t.co/uT3GFRcG2i',
#   'Revelry',
#   'https://t.co/MHb8508uVg',
#   'https://t.co/zHvdnWdlLs',
#   'https://t.co/iQ3poB7bsJ',
#   '31',
#   'Palisades',
#   '@mykung',
#   'BCS',
#   'blasting',
#   'Whittake',
#   'https://t.co/rcGhKIy3qz',
#   'confident',
#   'beasty',
#   'personally',
#   'kershaw',
#   '@CarolinaaaaaaE',
#   '@TheGirlisFree',
#   'rotten',
#   'Vans',
#   '@WeAre2012',
#   'snark',
#   'soldier',
#   'https://t.co/xnrm83uXGh',
#   'journalism',
#   'Oakwood',
#   '@foxnewslatino',
#   'Importance',
#   '@sbeeton76',
#   'Bowls',
#   'Meat',
#   'Col',
#   '@gjergjdollani',
#   '#Poetry',
#   'largest',
#   'https://t.co/JfdbdUVBxQ',
#   'amilly',
#   'Penang',
#   '#Seattle',
#   'recognise',
#   'NIC',
#   '@saiknicole',
#   '@RyanSchuiling',
#   '29-27',
#   'publicly',
#   'shaped',
#   'ofc',
#   'boo',
#   'transmission',
#   'offshore',
#   'possessions',
#   '#drlove',
#   '@GMA',
#   'https://t.co/Rx2JTxzwja',
#   '@wigmore_hall',
#   'Too',
#   '万佛林',
#   'very',
#   'libs',
#   'likeBut',
#   '@manda__maee',
#   'stands',
#   'upcoming',
#   'credible',
#   '7D',
#   'https://t.co/ZNpmLm6HAM',
#   '204A',
#   'Vikram',
#   'unassigned',
#   'gallery',
#   'Disrespect',
#   'NE7',
#   'https://t.co/WHmx67krZf',
#   'https://t.co/Hu9WDmylwg',
#   'demolition',
#   'since',
#   'https://t.co/z2jEILLveJ',
#   'Aaaaaaaaa',
#   'https://t.co/udsybcrbKN',
#   '#Austin',
#   '@naturallydiff',
#   'Shoppers',
#   'austin',
#   '#KhizrKhan',
#   'daysssssss',
#   '@jackbuckby',
#   'https://t.co/y1WXaK9ROG',
#   'jesus',
#   'Note',
#   'Kirman',
#   'benn',
#   'Kersh',
#   'regenerate',
#   'Cowardly',
#   'Ruben',
#   'https://t.co/4xNaTi4M6U',
#   'https://t.co/bf04jqElI1',
#   'Passive',
#   'grips',
#   '19946',
#   'Query',
#   '09',
#   'Pretenders',
#   'rihanna',
#   '#Duluth',
#   '@Hatsta',
#   '12hr',
#   '@jonstonevideo',
#   '@EmmaWilkins12',
#   '#2A',
#   'Holbeach',
#   'https://t.co/MiL3WPNalS',
#   'Jayson',
#   'songwriter',
#   'okay',
#   '#Chicago',
#   'Something',
#   'non-board',
#   'EMAILS',
#   'https://t.co/9rRilBcfy7',
#   'fountains',
#   'https://t.co/u0Ll5ve2cG',
#   '@babs200475',
#   'Total',
#   'EVER',
#   '@irahh1004',
#   '#nyt',
#   '#workday',
#   '#Montana',
#   '#IKON2016',
#   '#Pinksocks',
#   '#RHFAJobs',
#   'Venus',
#   'https://t.co/frJ8Hm2voq',
#   '@antushmorgan',
#   'ftom',
#   'Pikachus',
#   'soda',
#   'Hornyyy',
#   'https://t.co/AahYMaAE56',
#   '77131',
#   'platform',
#   'Tree',
#   '#breakfast',
#   'see',
#   'Lemon',
#   'Expwy',
#   'Houston',
#   '@bpbrewing',
#   'https://t.co/xrBFrJBb0q',
#   'Rexton',
#   'leaders',
#   'coffee',
#   'Elliott',
#   'https://t.co/SIH6XKw0Tk',
#   'https://t.co/OuIu8JZAsZ',
#   '#SupperIsNotFattening',
#   'Surly',
#   '@FayeGrim',
#   'Export',
#   'Spark',
#   'ect',
#   'minee',
#   'https://t.co/lNH37f4VR0',
#   '@leehsienloong',
#   '#leaders',
#   'Shift',
#   'haunted',
#   'Custard',
#   '#Whitesboro',
#   'rating',
#   '@hzhenhao',
#   'SUPPORTING',
#   'officially',
#   '@Trasufoma',
#   'reason',
#   'hmbbbb',
#   'trauma',
#   'Anxiously',
#   'ran',
#   'Vote',
#   'Wtf',
#   'Donny',
#   'PHOTO',
#   'https://t.co/H6RvKaxnsy',
#   'next',
#   '1943',
#   'Pristina',
#   '@afflictionate',
#   'https://t.co/6dE7Zicbim',
#   'dollars',
#   '@LFC',
#   '#reigning',
#   'grief',
#   'Asyraf',
#   'fluctuating',
#   'Primary',
#   '#PulisNaMatulis',
#   '#Germany',
#   '@QY_char',
#   'https://t.co/wSnkcEnFqF',
#   'GABF',
#   'amnt',
#   'glass',
#   '2407201',
#   'CNBC',
#   'YSlow',
#   'AIDS',
#   'https://t.co/6UUFb7ULRg',
#   'https://t.co/tx8zQiQTME',
#   'FLOWER',
#   'hibiscus',
#   'Affin',
#   'Fluff',
#   'enchantment',
#   'https://t.co/Gc9R0Z6Xck',
#   'bites',
#   'grieving',
#   '#Leafs',
#   'Solihull',
#   'https://t.co/BtM7jg5pzr',
#   'brushing',
#   'revenge',
#   'Musk',
#   'bricks',
#   '#tanchuanjin',
#   'https://t.co/vb2vkHVrlu',
#   '#ANNAPOLIS',
#   '@ekctafc',
#   '#singer',
#   'https://t.co/SQLCpSJEdw',
#   '@binacakracafe',
#   'Senate',
#   '444',
#   'https://t.co/TIV7D5aRmM',
#   'Borghesan',
#   'dilepaskan',
#   'Drink',
#   'MostTerrifyg',
#   'ruck',
#   'luka',
#   'Santorini',
#   'substandard',
#   'Sri',
#   '#I90',
#   '@jupitersignal',
#   '@chrissyteigen',
#   'farming',
#   '#blsawards',
#   '@London_Forum',
#   '@Phillies',
#   'kak',
#   '@SSGCoreJJ',
#   'https://t.co/bL1DH5xKp0',
#   'Elliman',
#   'https://t.co/VUoPdluOkP',
#   '#TNPLeagueCup3',
#   'Gannel',
#   'https://t.co/QJdlnCU1wd',
#   '@duckdownjames',
#   'Krispy',
#   "ppl's",
#   'Rail',
#   '#Clinical',
#   '@lynnie26blue',
#   'QUADRANGLE',
#   'Mummy',
#   '@JoshHalliday',
#   '@TheDemocrats',
#   'FRIDAY',
#   'https://t.co/eWhT3cYwXg',
#   '@NewJerzeyBoy',
#   'Uni',
#   'https://t.co/ykMtrfKqyw',
#   'lit',
#   'Ok',
#   'wife',
#   '@zhiming__',
#   'https://t.co/ecn3ENlh5r',
#   'https://t.co/UYZX0BGmxT',
#   'Selecta',
#   'https://t.co/ZmwQuBtfod',
#   'https://t.co/CZaY4CcPbp…',
#   '#Stamford',
#   'muse',
#   'medium',
#   'https://t.co/Tfz9IAhVP7',
#   '@MT9345',
#   'Ruiz',
#   'Garth',
#   'https://t.co/3Po0R2JeWz',
#   'starhub',
#   'schemes',
#   'BOAT',
#   'Muddy',
#   'legends',
#   'Sentral',
#   'thug',
#   '#Creepy',
#   '@ZerkaaHD',
#   '@Marvel',
#   '@SamsungMobile',
#   '#SjSharks',
#   'ज',
#   'Androidhttps',
#   'REp',
#   'https://t.co/3eyV9qbI31',
#   'PR',
#   'STJOURNAL',
#   'translator',
#   '#Kallang',
#   'Priebus',
#   'https://t.co/Eb1Pr8ESDl',
#   'Rick',
#   '@wgcs_education',
#   '@DougNBC',
#   'https://t.co/soG2vm68Ti',
#   'Maggs',
#   'accross',
#   '@portilloshotdog',
#   '@EricTrump',
#   'Cent',
#   'dreaded',
#   'singtel',
#   'Bottega',
#   'https://t.co/xi4MOMTLzO',
#   'achieving',
#   'proved',
#   'Phoenix',
#   'https://t.co/WRIZNEjzOy',
#   'irredeemable',
#   'quit',
#   'punt',
#   'TRF',
#   'Chhokar',
#   'Pop',
#   'LOOKS',
#   'marching',
#   'shipment',
#   'Liffey',
#   '1968',
#   '28th',
#   'appreciating',
#   'https://t.co/pkpNuD9Sj9',
#   'conv',
#   'A505',
#   'Reading',
#   'Forgotten',
#   'stupidity',
#   'https://t.co/oIkmUbsw8a',
#   '@arkjeremy',
#   'https://t.co/QQoUSeqMvw',
#   'bukit',
#   '@brikeilarcnn',
#   'dave',
#   '@andrewhth',
#   'Brantley',
#   'That',
#   '@HiraIsabella',
#   'MP',
#   'All-Time',
#   'Comcast',
#   '@07',
#   'aesthetic',
#   'JT',
#   'thumbs',
#   'Pussy',
#   'Steffi',
#   'https://t.co/qE904LN9WN',
#   'Novi',
#   '#DropOutTrump',
#   'IMMIGRANTS',
#   '#partyballoonssssss',
#   'Hortons',
#   'https://t.co/iAbI1ZxjIc',
#   'Americas',
#   '#gopalthinktank',
#   'https://t.co/2mW4gxW8Av',
#   '@RalstonReports',
#   '@Keir_Starmer',
#   'napped',
#   'complexion',
#   'display',
#   '@TylerCombz',
#   'taxpayers',
#   "geraldine's",
#   'farmland',
#   '#BirthdayCard',
#   'examiners',
#   'dff',
#   '13.95',
#   'Puddle',
#   '@mike_pence',
#   '#ZionNationalPark',
#   'ROC',
#   'regimes',
#   'Overtown',
#   'https://t.co/j11934Wfpa',
#   'H',
#   'https://t.co/MwljU6HMwr',
#   'spunk',
#   "God's",
#   'blinders',
#   'https://t.co/EJXLq9OgED',
#   'Hous',
#   '@anastasiasforla',
#   'Yoko',
#   'Knn',
#   '#Mirzya',
#   'https://t.co/AjHP7X7jEs',
#   'cutie',
#   'https://t.co/a5Jwm9INgF',
#   "Oliver's",
#   'panadol',
#   '@MercedesAMGF1',
#   'https://t.co/OJD382bGlC',
#   '@robbysoave',
#   'SUPPORTS',
#   'https://t.co/iXIliOrwuw',
#   '#CapeCod',
#   'Hardy',
#   'Colbert',
#   "Gov't",
#   'rematch',
#   'Performed',
#   'woodland',
#   "women's",
#   'https://t.co/OYvBBSo1QO',
#   'Barbie',
#   'IPhone',
#   'Wacko',
#   'Putt',
#   'https://t.co/vn63ngYJqo',
#   'honeymoon',
#   'Offside',
#   'Alvin',
#   'Dunk',
#   'Cintas',
#   'https://t.co/hudHEJBZLt',
#   'Durbin',
#   'Year',
#   '_singapore',
#   'respectful',
#   '#ink',
#   '#telecaster',
#   'https://t.co/ygRNQNmh8Z',
#   '#hamilton',
#   'Push',
#   'MIKE',
#   'skates',
#   'Mechanical',
#   '#TheWoodlands',
#   '@ChrisHumphries5',
#   'flying',
#   'focus',
#   'https://t.co/BLkeaFmfxz',
#   'https://t.co/xrAi6n3YU6',
#   'CSF',
#   'Era',
#   'missiles',
#   'https://t.co/CsXxQ6Hpm2',
#   'Metro',
#   'polite',
#   'Khaled',
#   'dress',
#   'https://t.co/qxl945TH8h',
#   '@BrewDog',
#   'https://t.co/8ZVOsqhjMm',
#   '#TMLtalk',
#   'Federal',
#   'ceramic',
#   'https://t.co/BBgWsB6q1u',
#   'program',
#   'Conservative',
#   'Sky',
#   'sorry',
#   'Jam',
#   'https://t.co/97TivSDtJn',
#   'Sherborne',
#   'Headlines',
#   'paired',
#   '8am',
#   'connecting',
#   'https://t.co/3lAxiEYpv6',
#   'tropppp',
#   'Timeline',
#   'american',
#   '#kravmagaspokane',
#   'https://t.co/MPzmy3No4L',
#   '#Sydney',
#   'WONDER',
#   'Prescribe',
#   '@GingerPimpernel',
#   '@JamTarts',
#   'https://t.co/gG2Rtd19vN',
#   '@Scientits',
#   'Stones',
#   'iceland',
#   'i.tea',
#   'Firm',
#   'chinese',
#   '@Creative_Fed',
#   'K-SB',
#   '@theninthnight',
#   'Experienced',
#   'Jump',
#   '@theberwickshire',
#   'TO',
#   'routing',
#   'fetus',
#   'Logistics',
#   'Conn',
#   'HATTY',
#   '1275',
#   'Lakebay',
#   '美美',
#   'Pooh',
#   'https://t.co/7HqSB6mwgT',
#   'revolution',
#   '@Bill_Roose',
#   'https://t.co/JB3pBpzfax',
#   '@jllllanbanks',
#   'facilities',
#   '@MarkAll21',
#   '#STWM',
#   'https://t.co/U4PlstFv8N',
#   'programmes',
#   'allegedly',
#   '@k4vrielxz',
#   'apocalypse',
#   'aint',
#   'https://t.co/rfaTQUE1Tx',
#   'voters',
#   '@Cookycraig',
#   'LSU',
#   '@MerlinapUK',
#   'Willian',
#   '@lorediazquijano',
#   'Acceptable',
#   '#percheron',
#   'Markets',
#   '@LeVoughnJames',
#   'Lucas',
#   'violent',
#   'Lucerne',
#   'https://t.co/zbjzgVPxwz',
#   'fs',
#   '#rwsentosa',
#   'Dynamic',
#   'mdfleetweek',
#   'Arson',
#   'willing',
#   'Leicester',
#   'disingenuous',
#   'Steelers',
#   'experie',
#   "Tour's",
#   'Scots',
#   'Therapists',
#   'Deanna',
#   'Labor',
#   'Amphora',
#   'mechanical',
#   'https://t.co/XChQf9RIN3',
#   '1s',
#   "SHOULDN'T",
#   'Stage',
#   'Ps-more',
#   '@watudodnthaizme',
#   'immense',
#   'https://t.co/M2DYpjJEXd',
#   'Open',
#   'Missile',
#   '#bigdata',
#   'https://t.co/AYb0moMRwV',
#   'Greene',
#   'melting',
#   '@CMPunk',
#   'cotton',
#   '#Bug',
#   'https://t.co/ZPgsfKp8WO',
#   '#whatdayisit',
#   'https://t.co/I254udxfz8',
#   'Foreign',
#   '182k',
#   'FUCGIN',
#   '#boibye',
#   'Caterpillar',
#   'Manisha',
#   'Hilll',
#   'housing',
#   '@moorejohn',
#   '#TheWailing',
#   'Nobar',
#   '@LePetitGuDaab',
#   '@mikeybarone',
#   'Shaheera',
#   'Greetings',
#   '@RockyHorrorFOX',
#   'tips',
#   'Lissie',
#   'silencing',
#   'Proper',
#   '@DubCityCouncil',
#   '@wkyc',
#   'https://t.co/YRbX1T1NRJ',
#   '@railtrailfbco',
#   '@iisfarzana',
#   'attorney',
#   'Scholar',
#   'tandoori',
#   '@Agence_EBP',
#   'spencer',
#   'fa',
#   'Limassol',
#   '#clintonsoros2016',
#   'Move',
#   '#SmartMoves',
#   '#seattledogs',
#   'peeps',
#   'Promenade',
#   'https://t.co/4Q2EPqOdAM',
#   '@chet_',
#   'restoring',
#   'Genesee',
#   '#KILLINGFIELD',
#   '#thefall',
#   '@AerLingus',
#   '#feelinggrateful',
#   'Huggies',
#   'Sallehin',
#   'stall',
#   'Sharma',
#   'prayers',
#   '@e4chelsea',
#   'analysts',
#   'waxed',
#   'Vanek',
#   '@BBC',
#   '@EnvAgency',
#   'calledMe',
#   'Benson',
#   'Rogelio',
#   '@keithroland1',
#   'Pitt',
#   'Goosebumps',
#   '#Melbourne',
#   'analogy',
#   't.co/G1Tz28pCgt',
#   'https://t.co/LBwe0Qwtde',
#   'airtime',
#   'Glow',
#   '#NUS',
#   'Shelter',
#   'uuummmmmm',
#   '#MJ',
#   ...},
#  'y_set': {'B-negative',
#   'B-neutral',
#   'B-positive',
#   'I-negative',
#   'I-neutral',
#   'I-positive',
#   'O'}}

# %% [markdown]
# ### Part 2a: (5 pts) Write a function that estimates the emission parameters from the training set using MLE (maximum likelihood estimation):

# %%
#e(x|y) = Count(y -> x)/Count(y)
#Count(y->x) means number of times you see x generated from y

import pandas as pd
import numpy as np

def calculate_emission_count(parsed_data):
    data = parsed_data['data']
    x_set = parsed_data['x_set']
    y_set = parsed_data['y_set']
    #create a new datafram of zeros with keys (ie.tweets) as the index and sentiments as the columns
    count_emissions_df = pd.DataFrame(np.zeros((len(x_set),len(y_set))),index=x_set,columns=y_set)
    count_y = pd.Series(np.zeros(len(y_set)),index=y_set) #create a series object of zeros with index as the sentiments => to store the number times the sentiments appear
    #print(count_y)
    #print(count_emissions_df) #datafram structure: where its tweets against columns of sentiments
    
    for word in data:
        #print(word) #format of data => [[keys],[values]]
        #keys are the tweets, values are the sentiments
        tweets_data,sentiments_data = word
        
        for i in range(len(tweets_data)):
            tweet,sentiment = tweets_data[i],sentiments_data[i] #associate the tweet with its sentiment
            #print(tweet,sentiment)
            #print(sentiment)
            #+1 to the row,col, given the tweet, sentiment freq +1
            count_emissions_df.loc[tweet,sentiment] += 1 #.loc[] access a grp of rows and columns by labels
            #count_emissions_df is for Count(y->x) [counting the number of times a sentiment wrt to the tweet]
            count_y[sentiment] += 1 #incrementing the number of time the respective sentiment appear
    return count_emissions_df,count_y
    
def get_emission_params(parsed_data):
    count_emissions_df,count_y = calculate_emission_count(parsed_data)
    return count_emissions_df/count_y #e(x|y), where x is the tweet, and y is the sentiment


em_df = get_emission_params(obtain_data('sg_train'))
#get_emission_counts(obtain_data('sg_train'))
em_df.head()
# Out:
#                          B-positive         O  B-negative  I-positive  \
# https://t.co/OgZ1pIXiSD    0.000000  0.000008         0.0    0.000000
# ean                        0.000000  0.000000         0.0    0.000000
# Cambridge                  0.000154  0.000000         0.0    0.000704
# Mugen                      0.000000  0.000000         0.0    0.000235
# @eddiesjb_                 0.000000  0.000004         0.0    0.000000
#
#                          I-neutral  B-neutral  I-negative
# https://t.co/OgZ1pIXiSD    0.00000   0.000000         0.0
# ean                        0.00006   0.000000         0.0
# Cambridge                  0.00012   0.000168         0.0
# Mugen                      0.00000   0.000056         0.0
# @eddiesjb_                 0.00000   0.000000         0.0

# %%
a=[['Omg', "I'm", 'craving', 'UK', 'food', 'so', 'much', 'right', 'now', 'and', 'all', 'I', 'wanna', 'do', 'is', 'go', 'to', 'tescos', 'Mini', 'cheddars', ',', "Terry's", 'chocolate', 'orange', 'and', 'a', 'jam', 'donut', 'PLZZZZZ'], ['O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'I-positive', 'I-positive', 'O', 'B-positive', 'I-positive', 'I-positive', 'O', 'O', 'B-positive', 'I-positive', 'O']]

x,y = a

print(x)
print(y)
# Out:
# ['Omg', "I'm", 'craving', 'UK', 'food', 'so', 'much', 'right', 'now', 'and', 'all', 'I', 'wanna', 'do', 'is', 'go', 'to', 'tescos', 'Mini', 'cheddars', ',', "Terry's", 'chocolate', 'orange', 'and', 'a', 'jam', 'donut', 'PLZZZZZ']
# ['O', 'O', 'O', 'B-positive', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-positive', 'I-positive', 'I-positive', 'O', 'B-positive', 'I-positive', 'I-positive', 'O', 'O', 'B-positive', 'I-positive', 'O']

# %% [markdown]
# ### Part 2b) (10 pts) One problem with estimating the emission parameters is that some words that appear in the test set do not appear in the training set. One simple idea to handle this issue is as follows. First, replace those words that appear less than k times in the training set with a special token #UNK# before training. This leads to a “modiﬁed training set”. We then use such a modiﬁed training set to train our model. During the testing phase, if the word does not appear in the “modiﬁed training set”, we replace that word with #UNK# as well. Set k to 1, implement this ﬁx into your function for computing the emission parameters.

# %%
def calculate_new_emission_counts(parsed_data,k):
    count_emissions_df,count_y = calculate_emission_count(parsed_data)
    #.sum(axis = 1(sum the column), axis = 0 (sum the index))
    count_tweet_appearance = count_emissions_df.sum(axis=1)
    #print(count_tweet_appearance) #counting the number of times each tweet appears by summing everything across the columns
    '''Output of count_tweet appearance eg. 
        seems                      15.0
        https://t.co/h6Ie4IBJ08     1.0
        #AnnaVonHausswolff          2.0
        Bowery                      2.0
        refuge                      2.0
        @chuckielufc                1.0
        https://t.co/7xSNeWemp1     1.0
        @chris_steller              3.0
        unexpected                  3.0
        #usantdp                    1.0
        Ones                        2.0
        1979                        4.0
        @joceltsh                   1.0
        @TomBoxingAsylum            2.0
        @thistletat13               2.0
        @eibeibb                    2.0
        @TalatHussain12             1.0
        Ilkeston                    2.0
        @ricosua                    1.0
        Belarus                     2.0
        charms                      2.0
        @EvermorSolution            2.0
        https://t.co/WrcuWKQ0Xg     2.0
        FIRED                       2.0'''
    
    failed_tweets = count_tweet_appearance[count_tweet_appearance<k]
    #print(failed_tweets)
    '''eg output if k<3 (ie. tweets with occurence less than 3 times) is:
        @Nandos                    1.0
        @rcmpgrcpolice             1.0
        #yas                       1.0
        @just                      2.0
        ford                       1.0
        attracted                  2.0
        @Unitetheunion             1.0
        .....        '''
    
    #replace the tweets that occur less than 1.0 with "#UNK#"
    #print(failed_tweets.index) #gives all the tweets that <1.0
    
    replace_tweets = count_emissions_df.loc[failed_tweets.index].sum(axis=0)
    replace_tweets.name  = '#UNK#'
    
    new_df = count_emissions_df.append(replace_tweets)
    new_df = new_df.drop(failed_tweets.index,axis=0) #drop all failed_tweets words
    headers = new_df.dtypes.index
    #print(headers[4]) #gives sentiment O
    new_df.at['#UNK#',headers[4]] = 1.0
    #print(new_df) #without failed_tweets words inside, has #UNK# row inside at the bottom
    
    return new_df, count_y

def get_new_emission_params(parsed_data,k):
    count_emissions_df,count_y = calculate_new_emission_counts(parsed_data,k)
    return count_emissions_df/count_y #e(x|y), where x is the tweet, and y is the sentiment

#calculate_new_emission_counts(obtain_data('sg_train'),3)
new_em_df_parameters = get_new_emission_params(obtain_data('sg_train'),1)
#new_em_df_parameters.sum(axis=1) #gives the sum of each rows (individual respective words)
'''eg.
Throwing          0.000012
headquarters      0.000300
insist            0.000012
except            0.000071
Broken            0.000128
LCD               0.000124
occur             0.000012
sound             0.000071
'''

#new_em_df_parameters.sum(axis=0) #gives the counts of the sentiments
new_em_df_parameters.tail()
# Out:
#           B-positive         O  B-negative  I-positive  I-neutral  B-neutral  \
# cow         0.000154  0.000012         0.0    0.000000    0.00000        0.0
# taxonomy    0.000000  0.000008         0.0    0.000000    0.00000        0.0
# Fetus       0.000154  0.000000         0.0    0.000000    0.00000        0.0
# Killeen     0.000000  0.000000         0.0    0.000235    0.00000        0.0
# #UNK#       0.000000  0.000000         0.0    0.000000    0.00006        0.0
#
#           I-negative
# cow              0.0
# taxonomy         0.0
# Fetus            0.0
# Killeen          0.0
# #UNK#            0.0

# %%
#Note to self: what is axis=1, axis=0 for dataframe pandas
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://i.stack.imgur.com/dcoE3.jpg")
# Out:
# <img src="https://i.stack.imgur.com/dcoE3.jpg"/>

# %% [markdown]
# ### Part 2c Implement a simple sentiment analysis system that produces the tag => y∗ = argmax e(x|y)

# %%
def training_dataset(file):
    dataset = obtain_data(file)
    k = 1
    return get_new_emission_params(dataset,k)

#single sentiment analysis for a word
def sentiment_analysis(emission_param,x):
    #checking if the tweet is an undiscovered/discovered word
    #if the word does not appear in training set, then change it to #UNK#
    #print(emission_param.index) #gives the individual tweets
    if x not in emission_param.index:
        x = '#UNK#'
    probability = emission_param.loc[x,:]
   # print(probability)
    max_probability = None
    for col in probability.index:
        #print(col) #gives the sentiments labels
        '''B-positive
            ..
            ...
            -
            I-negative
            B-neutral
            242
            O
            477
            B-negative
            .
            I-positive
            I-neutral'''
        if max_probability is None : 
            max_probability = probability.loc[col]
            y = col
        elif probability.loc[col]>max_probability: #take the max prob
            max_probability = probability.loc[col]
            y = col #take the sentiment with the highest probability
        
    return y
        

def evaluation(filename,emission_param,outputfile):
    with open(filename,'r',encoding="utf8") as inputfile:
        lines = inputfile.readlines()
        lines = [line.replace('\n','') for line in lines]
        #print(lines)
        '''['best', 'friends', 'who', 'cry', 'on', 'FaceTime', 'together', ',', 'stay', 'together', '', "I'm", 'at', 'Starbucks',
        'in', 'Johor', 'Bahru', ',', 'Johor', 'w', '/', '@cassiecr17', 'https://t.co/3rzoTtjRag', '', 'Reports', 'of', 'a', 
        'collision', 'on', 'Friary', 'Road', 'in', 'Naas', 'https://t.co/MZgfLNdbyr', '', '♫', 'She', 'Moves', 'In', 'Her', 'Own' ......]
        '''
        
        for i in range(len(lines)):
            line = lines[i] #each individual tweets
            if line != '': #if line is not empty
                line = line + ' ' + sentiment_analysis(emission_param,line)
            line += '\n'
            lines[i] = line
            
        with open(outputfile,"w",encoding="utf8") as outputfile:
            for line in lines:
                outputfile.write(line)
    print("evaluation completed!")

# %%
modified_em_params = get_new_emission_params(obtain_data('sg_train'),1)
word = '.'
try:
    print(modified_em_params.loc[word])
except:
    word = '#UNK#'
    print(modified_em_params.loc[word])
sentiment_analysis(modified_em_params,word)
# Out:
# B-positive    0.000000
# O             0.030363
# B-negative    0.000000
# I-positive    0.015486
# I-neutral     0.009963
# B-neutral     0.000000
# I-negative    0.021164
# Name: ., dtype: float64
# 'O'

# %%
emission_param = training_dataset('SG/train')
evaluation('SG/dev.in',emission_param,'SG/dev.p2.out')
# Out:
# evaluation completed!

# %%
#doing it for all 4 countries
for cty in ["CN","EN","FR","SG"]:
    emission_params = training_dataset(cty+"/train") #new emission params are also obtained inside here
    print("Analysing for " + cty + " dataset:")
    evaluation(cty+"/dev.in",emission_params,cty+"/dev.p2.out")
# Out:
# Analysing for CN dataset:
# evaluation completed!
# Analysing for EN dataset:
# evaluation completed!
# Analysing for FR dataset:
# evaluation completed!
# Analysing for SG dataset:
# evaluation completed!

# %%
import sys
import re
from copy import copy
from collections import defaultdict
from optparse import OptionParser

#Read entities from predcition
def get_predicted(predicted, answers=defaultdict(lambda: defaultdict(defaultdict))):

    example = 0
    word_index = 0
    entity = []
    last_ne = "O"
    last_sent = ""
    last_entity = []

    answers[example] = []
    for line in predicted:
        line = line.strip()
        if line.startswith("##"):
            continue
        elif len(line) == 0:
            if entity:
                answers[example].append(list(entity))
                entity = []

            example += 1
            answers[example] = []
            word_index = 0
            last_ne = "O"
            continue
        else:
            split_line = line.split(separator)
            #word = split_line[0]
            value = split_line[outputColumnIndex]
            ne = value[0]
            sent = value[2:]


            last_entity = []

            #check if it is start of entity
            if ne == 'B' or (ne == 'I' and last_ne == 'O') or (last_ne != 'O' and ne == 'I' and last_sent != sent):
                if entity:
                    last_entity = list(entity)

                entity = [sent]
                    
                entity.append(word_index)

            elif ne == 'I':
                entity.append(word_index)

            elif ne == 'O':
                if last_ne == 'B' or last_ne == 'I':
                    last_entity =list(entity)
                entity = []


            if last_entity:
                answers[example].append(list(last_entity))
                last_entity = []

        last_sent = sent
        last_ne = ne
        word_index += 1

    if entity:
        answers[example].append(list(entity))


    return answers



#Read entities from gold data
def get_observed(observed):


    example = 0
    word_index = 0
    entity = []
    last_ne = "O"
    last_sent = ""
    last_entity = []

    observations=defaultdict(defaultdict)
    observations[example] = []

    for line in observed:
        line = line.strip()
        if line.startswith("##"):
            continue
        elif len(line) == 0:
            if entity:
                observations[example].append(list(entity))
                entity = []

            example += 1
            observations[example] = []
            word_index = 0
            last_ne = "O"
            continue

        else:
            split_line = line.split(separator)
            word = split_line[0]
            value = split_line[outputColumnIndex]
            ne = value[0]
            sent = value[2:]


            last_entity = []

            #check if it is start of entity, suppose there is no weird case in gold data
            if ne == 'B' or (ne == 'I' and last_ne == 'O') or (last_ne != 'O' and ne == 'I' and last_sent != sent):
                if entity:
                    last_entity = entity

                entity = [sent]
                    
                entity.append(word_index)

            elif ne == 'I':
                entity.append(word_index)

            elif ne == 'O':
                if last_ne == 'B' or last_ne == 'I':
                    last_entity = entity
                entity = []


            if last_entity:
                observations[example].append(list(last_entity))
                last_entity = []


        last_ne = ne
        last_sent = sent
        word_index += 1

    if entity:
        observations[example].append(list(entity))

    return observations

#Print Results and deal with division by 0
def printResult(evalTarget, num_correct, prec, rec):
    if abs(prec + rec ) < 1e-6:
        f = 0
    else:
        f = 2 * prec * rec / (prec + rec)
    print('#Correct', evalTarget, ':', num_correct)
    print(evalTarget, ' precision: %.4f' % (prec))
    print(evalTarget, ' recall: %.4f' %   (rec))
    print(evalTarget, ' F: %.4f' % (f))

#Compare results bewteen gold data and prediction data
def compare_observed_to_predicted(observed, predicted):

    correct_sentiment = 0
    correct_entity = 0

    total_observed = 0.0
    total_predicted = 0.0

    #For each Instance Index example (example = 0,1,2,3.....)
    for example in observed:

        if example in discardInstance:
            continue

        observed_instance = observed[example]
        predicted_instance = predicted[example]

        #Count number of entities in gold data
        total_observed += len(observed_instance)
        #Count number of entities in prediction data
        total_predicted += len(predicted_instance)

        #For each entity in prediction
        for span in predicted_instance:
            span_begin = span[1]
            span_length = len(span) - 1
            span_ne = (span_begin, span_length)
            span_sent = span[0]

            #For each entity in gold data
            for observed_span in observed_instance:
                begin = observed_span[1]
                length = len(observed_span) - 1
                ne = (begin, length)
                sent = observed_span[0]

                #Entity matched
                if span_ne == ne:
                    correct_entity += 1


                    #Entity & Sentiment both are matched
                    if span_sent == sent:
                        correct_sentiment += 1

    print()
    print('#Entity in gold data: %d' % (total_observed))
    print('#Entity in prediction: %d' % (total_predicted))
    print()

    prec = correct_entity/total_predicted
    rec = correct_entity/total_observed
    printResult('Entity', correct_entity, prec, rec)
    print()

    prec = correct_sentiment/total_predicted
    rec = correct_sentiment/total_observed
    printResult('Entity Type',correct_sentiment, prec, rec)




##############Main Function##################

if len(sys.argv) < 3:
    print ('Please make sure you have installed Python 3.4 or above!')
    print ("Usage on Windows:  python evalResult.py [gold file] [prediction file]")
    print ("Usage on Linux/Mac:  python3 evalResult.py [gold file] [prediction file]")
    sys.exit()

gold = open('FR\dev.out', "r", encoding='UTF-8')
prediction = open('FR\dev.p2.out', "r", encoding='UTF-8')
discardInstance = []


if len(sys.argv) > 3 and sys.argv[3] == 'filter':
    filterInst_file = open(sys.argv[1] + '.filter', "r", encoding='UTF-8')
    for line in filterInst_file:
        line = line.strip('\n')
        line = line.strip('\r')
        instID = int(line)
        discardInstance.append(instID)


#column separator
separator = ' '

#the column index for tags
outputColumnIndex = 1
#Read Gold data
observed = get_observed(gold)

#Read Predction data
predicted = get_predicted(prediction)

#Compare
compare_observed_to_predicted(observed, predicted)
# Out:
# #Entity in gold data: 238
# #Entity in prediction: 1128
#
# #Correct Entity : 186
# Entity  precision: 0.1649
# Entity  recall: 0.7815
# Entity  F: 0.2723
#
# #Correct Entity Type : 78
# Entity Type  precision: 0.0691
# Entity Type  recall: 0.3277
# Entity Type  F: 0.1142

# %% [markdown]
# ##### >python3 evalResult.py EN/dev.out EN/dev.p2.out
# Entity in gold data: 802
# Entity in prediction: 926
#
# Correct Entity : 576
# Entity  precision: 0.6220
# Entity  recall: 0.7182
# Entity  F: 0.6667
#
# Correct Entity Type : 507
# Entity Type  precision: 0.5475
# Entity Type  recall: 0.6322
# Entity Type  F: 0.5868

# %% [markdown]
# ###### >python3 evalResult.py CN/dev.out CN/dev.p2.out
# Entity in gold data: 1081
# Entity in prediction: 4939
#
# Correct Entity : 613
# Entity  precision: 0.1241
# Entity  recall: 0.5671
# Entity  F: 0.2037
#
# Correct Entity Type : 436
# Entity Type  precision: 0.0883
# Entity Type  recall: 0.4033
# Entity Type  F: 0.1449

# %% [markdown]
# ###### >python3 evalResult.py FR/dev.out FR/dev.p2.out
# Entity in gold data: 238
# Entity in prediction: 1128
#
# Correct Entity : 186
# Entity  precision: 0.1649
# Entity  recall: 0.7815
# Entity  F: 0.2723
#
# Correct Entity Type : 78
# Entity Type  precision: 0.0691
# Entity Type  recall: 0.3277
# Entity Type  F: 0.1142

# %% [markdown]
# ###### >python3 evalResult.py SG/dev.out SG/dev.p2.out
# Entity in gold data: 4092
# Entity in prediction: 11598
#
# Correct Entity : 2291
# Entity  precision: 0.1975
# Entity  recall: 0.5599
# Entity  F: 0.2920
#
# Correct Entity Type : 1315
# Entity Type  precision: 0.1134
# Entity Type  recall: 0.3214
# Entity Type  F: 0.1676
